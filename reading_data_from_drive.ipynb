# %% [markdown]
# <a href="https://colab.research.google.com/github/isiktopcu/bart/blob/main/reading_data_from_drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q PyDrive

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import pandas as pd

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
#sharable link
file_link = "link"
file_id = file_link.split("/")[5]

# pyDrive file object
fileDownloaded = drive.CreateFile({'id': file_id})
# load the csv file into memory
fileDownloaded.GetContentFile('example.csv')
df = pd.read_csv('example.csv')
df.head()
# Out:
#               tweet_id                 created_at            author_id  \
# 0  1364706762021036049  2021-02-24 22:40:21+00:00            140928235
# 1  1364693518141317123  2021-02-24 21:47:44+00:00  1252910981837197312
# 2  1364692142623518725  2021-02-24 21:42:16+00:00           1245292034
# 3  1364683705760047112  2021-02-24 21:08:44+00:00   799091124925300738
# 4  1364680573294362625  2021-02-24 20:56:17+00:00  1254085182442876928
#
#            place_id  place_name         full_place_name       lat       long  \
# 0  60bd9047be319459  Westhumble  Westhumble, South East -0.330245  51.254466
# 1  30dba570f454bbac     Rushden        Rushden, England -0.603826  52.289506
# 2  53b67b1d1cc81a51  Birmingham     Birmingham, England -1.890640  52.493966
# 3  68f3012fe4848e35     Cardiff          Cardiff, Wales -3.179800  51.497002
# 4  5434fc88dcd5444b  Alexandria    Alexandria, Scotland -4.574872  55.987019
#
#    exact_coords                                        bbox  ...  \
# ...

# %%
df.shape
# Out:
# (34490, 38)
